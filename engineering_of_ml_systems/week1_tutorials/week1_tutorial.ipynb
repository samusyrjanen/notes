# %% [markdown]
# This notebook introduces the MLOps platform you will be using in this course. The notebook first provides an overview of the platform's architecture and then links you to the tutorials that help you prepare for this week's assignments.
#
# # An introduction to the MLOps platform
# ### Overview
# The overview of the MLOps platform is illustrated in the following figure.
#
# ![](./images/overview.jpg)
#
# The MLOps platform has three main components: Kubeflow Pipelines, MLflow, and KServe.
#
# **[Kubeflow Pipelines](https://www.kubeflow.org/docs/components/pipelines/v2/introduction/)** is an open-source ML task orchestrator. It allows users to define an ML pipeline, which is a way to codify and automate a set of predefined tasks, such as data preprocessing, model training, and model deployment, to produce an ML model. Kubeflow Pipelines allows for managing the dependencies and execution orders of tasks. Kubeflow Pipelines runs atop a Kubernetes cluster and can run multiple ML pipelines in parallel by leveraging the resources of the cluster.
#
# **[MLflow](https://mlflow.org/docs/latest/index.html)** is an open-source platform for managing ML experiments. It is used to record model training metadata (e.g., hyperparameters), training datasets, and metrics (e.g., the evaluation metrics obtained when the model is evaluated against a testing dataset). MLflow also provides the feature of saving model artifacts in a central place. In the MLOps platform, MLflow is deployed as a service, which provides endpoints for recording model training metadata and saving model artifacts. As shown in the figure above, MLflow uses a [PostgreSQL database](https://www.postgresql.org/) as metadata store for saving the training metadata and an [MinIO storage](https://min.io/) as an artifact store for persisting training artifacts, e.g. model artifacts, text, and datasets.
#
# **[KServe](https://kserve.github.io/website/0.10/)** is an open-source model serving platform built atop Kubernetes. It is designed to simplify the deployment and management of machine learning models in production environments. KServe leverages Kubernetes to provide the necessary infrastructure and capabilities for deploying and scaling ML models. In more details, upon receiving a model deployment request, KServe fetches the model artifact from defined storage (the MinIO storage service in our platform). It then packages the model artifact as a container and provides HTTP and gRPC APIs for querying predictions. KServe supports a wide range of model formats by default, such as SKLearn, XGBoost, LightGBM, TensorFlow, and PyTorch.
#
# ### Install needed packages
# Before going through the tutorials, you need to install the Python packages needed for this course.

# %%
# %pip install -r requirements.txt
# Out:
# Collecting scikit-learn==1.3.2 (from -r requirements.txt (line 1))
#   Downloading scikit_learn-1.3.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (10.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.8/10.8 MB 11.7 MB/s eta 0:00:00m eta 0:00:010:0101
# Requirement already satisfied: pandas~=1.5.3 in /home/user/anaconda3/envs/mlops_eng/lib/python3.10/site-packages (from -r requirements.txt (line 2)) (1.5.3)
# Collecting mlflow==2.3.2 (from -r requirements.txt (line 3))
#   Using cached mlflow-2.3.2-py3-none-any.whl (17.7 MB)
# Requirement already satisfied: google-cloud-storage~=1.44.0 in /home/user/anaconda3/envs/mlops_eng/lib/python3.10/site-packages (from -r requirements.txt (line 4)) (1.44.0)
# Requirement already satisfied: boto3~=1.28.62 in /home/user/anaconda3/envs/mlops_eng/lib/python3.10/site-packages (from -r requirements.txt (line 5)) (1.28.62)
# Requirement already satisfied: deepchecks~=0.17.4 in /home/user/anaconda3/envs/mlops_eng/lib/python3.10/site-packages (from -r requirements.txt (line 6)) (0.17.4)
# Requirement already satisfied: lightgbm~=3.3.5 in /home/user/anaconda3/envs/mlops_eng/lib/python3.10/site-packages (from -r requirements.txt (line 7)) (3.3.5)
# Collecting flask~=2.2.5 (from -r requirements.txt (line 8))
#   Downloading Flask-2.2.5-py3-none-any.whl (101 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 101.8/101.8 kB 7.9 MB/s eta 0:00:00
# Requirement already satisfied: click==8.0.4 in /home/user/anaconda3/envs/mlops_eng/lib/python3.10/site-packages (from -r requirements.txt (line 9)) (8.0.4)
# Collecting great_expectations~=0.17.17 (from -r requirements.txt (line 11))
#   Downloading great_expectations-0.17.23-py3-none-any.whl (5.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.4/5.4 MB 13.3 MB/s eta 0:00:000:00:01m eta 0:00:01
# Collecting thefuzz~=0.20.0 (from -r requirements.txt (line 12))
#   Downloading thefuzz-0.20.0-py3-none-any.whl (15 kB)
# Requirement already satisfied: optuna~=3.3.0 in /home/user/anaconda3/envs/mlops_eng/lib/python3.10/site-packages (from -r requirements.txt (line 14)) (3.3.0)
# Requirement already satisfied: psycopg2-binary~=2.9.6 in /home/user/anaconda3/envs/mlops_eng/lib/python3.10/site-packages (from -r requirements.txt (line 15)) (2.9.9)
# Requirement already satisfied: xgboost~=1.7 in /home/user/anaconda3/envs/mlops_eng/lib/python3.10/site-packages (from -r requirements.txt (line 16)) (1.7.6)
# Collecting plotly~=5.15.0 (from -r requirements.txt (line 17))
#   Downloading plotly-5.15.0-py2.py3-none-any.whl (15.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.5/15.5 MB 11.6 MB/s eta 0:00:00m eta 0:00:010:01:01
# Collecting joblib~=1.2.0 (from -r requirements.txt (line 18))
#   Downloading joblib-1.2.0-py3-none-any.whl (297 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 298.0/298.0 kB 12.4 MB/s eta 0:00:00
# Requirement already satisfied: kserve==0.10.1 in /home/user/anaconda3/envs/mlops_eng/lib/python3.10/site-packages (from -r requirements.txt (line 20)) (0.10.1)
# Requirement already satisfied: kfp==1.8.22 in /home/user/anaconda3/envs/mlops_eng/lib/python3.10/site-packages (from -r requirements.txt (line 22)) (1.8.22)
# Requirement already satisfied: numpy<2.0,>=1.17.3 in /home/user/anaconda3/envs/mlops_eng/lib/python3.10/site-packages (from scikit-learn==1.3.2->-r requirements.txt (line 1)) (1.26.0)
# Requirement already satisfied: scipy>=1.5.0 in /home/user/anaconda3/envs/mlops_eng/lib/python3.10/site-packages (from scikit-learn==1.3.2->-r requirements.txt (line 1)) (1.10.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/user/anaconda3/envs/mlops_eng/lib/python3.10/site-packages (from scikit-learn==1.3.2->-r requirements.txt (line 1)) (3.2.0)
# Requirement already satisfied: cloudpickle<3 in /home/user/anaconda3/envs/mlops_eng/lib/python3.10/site-packages (from mlflow==2.3.2->-r requirements.txt (line 3)) (2.2.1)
# Requirement already satisfied: databricks-cli<1,>=0.8.7 in /home/user/anaconda3/envs/mlops_eng/lib/python3.10/site-packages (from mlflow==2.3.2->-r requirements.txt (line 3)) (0.18.0)
# Requirement already satisfied: entrypoints<1 in /home/user/anaconda3/envs/mlops_eng/lib/python3.10/site-packages (from mlflow==2.3.2->-r requirements.txt (line 3)) (0.4)
# Requirement already satisfied: gitpython<4,>=2.1.0 in /home/user/anaconda3/envs/mlops_eng/lib/python3.10/site-packages (from mlflow==2.3.2->-r requirements.txt (line 3)) (3.1.37)
# Requirement already satisfied: pyyaml<7,>=5.1 in /home/user/.local/lib/python3.10/site-packages (from mlflow==2.3.2->-r requirements.txt (line 3)) (6.0)
# Requirement already satisfied: protobuf<5,>=3.12.0 in /home/user/anaconda3/envs/mlops_eng/lib/python3.10/site-packages (from mlflow==2.3.2->-r requirements.txt (line 3)) (3.20.3)
# Requirement already satisfied: pytz<2024 in /home/user/anaconda3/envs/mlops_eng/lib/python3.10/site-packages (from mlflow==2.3.2->-r requirements.txt (line 3)) (2023.3.post1)
# Requirement already satisfied: requests<3,>=2.17.3 in /home/user/anaconda3/envs/mlops_eng/lib/python3.10/site-packages (from mlflow==2.3.2->-r requirements.txt (line 3)) (2.31.0)
# Requirement already satisfied: packaging<24 in /home/user/anaconda3/envs/mlops_eng/lib/python3.10/site-packages (from mlflow==2.3.2->-r requirements.txt (line 3)) (23.0)
# Requirement already satisfied: importlib-metadata!=4.7.0,<7,>=3.7.0 in /home/user/anaconda3/envs/mlops_eng/lib/python3.10/site-packages (from mlflow==2.3.2->-r requirements.txt (line 3)) (6.8.0)
# Requirement already satisfied: sqlparse<1,>=0.4.0 in /home/user/anaconda3/envs/mlops_eng/lib/python3.10/site-packages (from mlflow==2.3.2->-r requirements.txt (line 3)) (0.4.4)
# Requirement already satisfied: alembic!=1.10.0,<2 in /home/user/anaconda3/envs/mlops_eng/lib/python3.10/site-packages (from mlflow==2.3.2->-r requirements.txt (line 3)) (1.12.0)
# Requirement already satisfied: docker<7,>=4.0.0 in /home/user/anaconda3/envs/mlops_eng/lib/python3.10/site-packages (from mlflow==2.3.2->-r requirements.txt (line 3)) (6.1.3)
# Requirement already satisfied: querystring-parser<2 in /home/user/anaconda3/envs/mlops_eng/lib/python3.10/site-packages (from mlflow==2.3.2->-r requirements.txt (line 3)) (1.2.4)
# Requirement already satisfied: sqlalchemy<3,>=1.4.0 in /home/user/anaconda3/envs/mlops_eng/lib/python3.10/site-packages (from mlflow==2.3.2->-r requirements.txt (line 3)) (2.0.21)
# Requirement already satisfied: pyarrow<12,>=4.0.0 in /home/user/anaconda3/envs/mlops_eng/lib/python3.10/site-packages (from mlflow==2.3.2->-r requirements.txt (line 3)) (11.0.0)
# Requirement already satisfied: markdown<4,>=3.3 in /home/user/anaconda3/envs/mlops_eng/lib/python3.10/site-packages (from mlflow==2.3.2->-r requirements.txt (line 3)) (3.5)
# Requirement already satisfied: matplotlib<4 in /home/user/anaconda3/envs/mlops_eng/lib/python3.10/site-packages (from mlflow==2.3.2->-r requirements.txt (line 3)) (3.8.0)
# Requirement already satisfied: gunicorn<21 in /home/user/anaconda3/envs/mlops_eng/lib/python3.10/site-packages (from mlflow==2.3.2->-r requirements.txt (line 3)) (20.1.0)
# Requirement already satisfied: Jinja2<4,>=2.11 in /home/user/.local/lib/python3.10/site-packages (from mlflow==2.3.2->-r requirements.txt (line 3)) (3.1.2)
# Requirement already satisfied: six>=1.16.0 in /home/user/anaconda3/envs/mlops_eng/lib/python3.10/site-packages (from kserve==0.10.1->-r requirements.txt (line 20)) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.8.0 in /home/user/anaconda3/envs/mlops_eng/lib/python3.10/site-packages (from kserve==0.10.1->-r requirements.txt (line 20)) (2.8.2)
# Requirement already satisfied: setuptools>=59.5.0 in /home/user/anaconda3/envs/mlops_eng/lib/python3.10/site-packages (from kserve==0.10.1->-r requirements.txt (line 20)) (67.8.0)
# Requirement already satisfied: urllib3>=1.26.8 in /home/user/anaconda3/envs/mlops_eng/lib/python3.10/site-packages (from kserve==0.10.1->-r requirements.txt (line 20)) (1.26.17)
# Requirement already satisfied: kubernetes>=18.20.0 in /home/user/anaconda3/envs/mlops_eng/lib/python3.10/site-packages (from kserve==0.10.1->-r requirements.txt (line 20)) (25.3.0)
# Collecting argparse>=1.4.0 (from kserve==0.10.1->-r requirements.txt (line 20))
#   Using cached argparse-1.4.0-py2.py3-none-any.whl (23 kB)
# Requirement already satisfied: minio<=7.1.3,>=4.0.9 in /home/user/anaconda3/envs/mlops_eng/lib/python3.10/site-packages (from kserve==0.10.1->-r requirements.txt (line 20)) (7.1.3)
# Requirement already satisfied: adal>=1.2.7 in /home/user/anaconda3/envs/mlops_eng/lib/python3.10/site-packages (from kserve==0.10.1->-r requirements.txt (line 20)) (1.2.7)
# Requirement already satisfied: tabulate>=0.9.0 in /home/user/anaconda3/envs/mlops_eng/lib/python3.10/site-packages (from kserve==0.10.1->-r requirements.txt (line 20)) (0.9.0)
# Requirement already satisfied: azure-storage-blob==12.9.0 in /home/user/anaconda3/envs/mlops_eng/lib/python3.10/site-packages (from kserve==0.10.1->-r requirements.txt (line 20)) (12.9.0)
# Requirement already satisfied: azure-storage-file-share==12.7.0 in /home/user/anaconda3/envs/mlops_eng/lib/python3.10/site-packages (from kserve==0.10.1->-r requirements.txt (line 20)) (12.7.0)
# Requirement already satisfied: azure-identity>=1.8.0 in /home/user/anaconda3/envs/mlops_eng/lib/python3.10/site-packages (from kserve==0.10.1->-r requirements.txt (line 20)) (1.14.0)
# Requirement already satisfied: cloudevents>=1.6.2 in /home/user/anaconda3/envs/mlops_eng/lib/python3.10/site-packages (from kserve==0.10.1->-r requirements.txt (line 20)) (1.10.0)
# Requirement already satisfied: avro>=1.11.0 in /home/user/anaconda3/envs/mlops_eng/lib/python3.10/site-packages (from kserve==0.10.1->-r requirements.txt (line 20)) (1.11.3)
# Requirement already satisfied: psutil>=5.9.0 in /home/user/anaconda3/envs/mlops_eng/lib/python3.10/site-packages (from kserve==0.10.1->-r requirements.txt (line 20)) (5.9.0)
# Requirement already satisfied: ray[serve]==2.0.0 in /home/user/anaconda3/envs/mlops_eng/lib/python3.10/site-packages (from kserve==0.10.1->-r requirements.txt (line 20)) (2.0.0)
# Requirement already satisfied: grpcio>=1.34.0 in /home/user/anaconda3/envs/mlops_eng/lib/python3.10/site-packages (from kserve==0.10.1->-r requirements.txt (line 20)) (1.43.0)
# Requirement already satisfied: tritonclient==2.18.0 in /home/user/anaconda3/envs/mlops_eng/lib/python3.10/site-packages (from kserve==0.10.1->-r requirements.txt (line 20)) (2.18.0)
# Requirement already satisfied: prometheus-client>=0.13.1 in /home/user/anaconda3/envs/mlops_eng/lib/python3.10/site-packages (from kserve==0.10.1->-r requirements.txt (line 20)) (0.13.1)
# Requirement already satisfied: orjson>=3.8.0 in /home/user/anaconda3/envs/mlops_eng/lib/python3.10/site-packages (from kserve==0.10.1->-r requirements.txt (line 20)) (3.9.7)
# Requirement already satisfied: httpx>=0.23.0 in /home/user/anaconda3/envs/mlops_eng/lib/python3.10/site-packages (from kserve==0.10.1->-r requirements.txt (line 20)) (0.25.0)
# Requirement already satisfied: fastapi<=0.88.0,>=0.85.0 in /home/user/anaconda3/envs/mlops_eng/lib/python3.10/site-packages (from kserve==0.10.1->-r requirements.txt (line 20)) (0.88.0)
# Requirement already satisfied: timing-asgi>=0.3.0 in /home/user/anaconda3/envs/mlops_eng/lib/python3.10/site-packages (from kserve==0.10.1->-r requirements.txt (line 20)) (0.3.1)
# Requirement already satisfied: absl-py<2,>=0.9 in /home/user/anaconda3/envs/mlops_eng/lib/python3.10/site-packages (from kfp==1.8.22->-r requirements.txt (line 22)) (1.4.0)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5 in /home/user/anaconda3/envs/mlops_eng/lib/python3.10/site-packages (from kfp==1.8.22->-r requirements.txt (line 22)) (2.12.0)
# Requirement already satisfied: google-api-python-client<2,>=1.7.8 in /home/user/anaconda3/envs/mlops_eng/lib/python3.10/site-packages (from kfp==1.8.22->-r requirements.txt (line 22)) (1.12.11)
# Requirement already satisfied: google-auth<3,>=1.6.1 in /home/user/anaconda3/envs/mlops_eng/lib/python3.10/site-packages (from kfp==1.8.22->-r requirements.txt (line 22)) (2.23.2)
# Requirement already satisfied: requests-toolbelt<1,>=0.8.0 in /home/user/anaconda3/envs/mlops_eng/lib/python3.10/site-packages (from kfp==1.8.22->-r requirements.txt (line 22)) (0.10.1)
# Requirement already satisfied: kfp-server-api<2.0.0,>=1.1.2 in /home/user/anaconda3/envs/mlops_eng/lib/python3.10/site-packages (from kfp==1.8.22->-r requirements.txt (line 22)) (1.8.5)
# Requirement already satisfied: jsonschema<5,>=3.0.1 in /home/user/anaconda3/envs/mlops_eng/lib/python3.10/site-packages (from kfp==1.8.22->-r requirements.txt (line 22)) (4.19.1)
# Requirement already satisfied: Deprecated<2,>=1.2.7 in /home/user/anaconda3/envs/mlops_eng/lib/python3.10/site-packages (from kfp==1.8.22->-r requirements.txt (line 22)) (1.2.14)
# Requirement already satisfied: strip-hints<1,>=0.1.8 in /home/user/anaconda3/envs/mlops_eng/lib/python3.10/site-packages (from kfp==1.8.22->-r requirements.txt (line 22)) (0.1.10)
# Requirement already satisfied: docstring-parser<1,>=0.7.3 in /home/user/anaconda3/envs/mlops_eng/lib/python3.10/site-packages (from kfp==1.8.22->-r requirements.txt (line 22)) (0.15)
# Requirement already satisfied: kfp-pipeline-spec<0.2.0,>=0.1.16 in /home/user/anaconda3/envs/mlops_eng/lib/python3.10/site-packages (from kfp==1.8.22->-r requirements.txt (line 22)) (0.1.16)
# Requirement already satisfied: fire<1,>=0.3.1 in /home/user/anaconda3/envs/mlops_eng/lib/python3.10/site-packages (from kfp==1.8.22->-r requirements.txt (line 22)) (0.5.0)
# Requirement already satisfied: uritemplate<4,>=3.0.1 in /home/user/anaconda3/envs/mlops_eng/lib/python3.10/site-packages (from kfp==1.8.22->-r requirements.txt (line 22)) (3.0.1)
# Requirement already satisfied: pydantic<2,>=1.8.2 in /home/user/anaconda3/envs/mlops_eng/lib/python3.10/site-packages (from kfp==1.8.22->-r requirements.txt (line 22)) (1.10.13)
# Requirement already satisfied: typer<1.0,>=0.3.2 in /home/user/anaconda3/envs/mlops_eng/lib/python3.10/site-packages (from kfp==1.8.22->-r requirements.txt (line 22)) (0.9.0)
# Requirement already satisfied: azure-core<2.0.0,>=1.10.0 in /home/user/anaconda3/envs/mlops_eng/lib/python3.10/site-packages (from azure-storage-blob==12.9.0->kserve==0.10.1->-r requirements.txt (line 20)) (1.29.4)
# Requirement already satisfied: msrest>=0.6.21 in /home/user/anaconda3/envs/mlops_eng/lib/python3.10/site-packages (from azure-storage-blob==12.9.0->kserve==0.10.1->-r requirements.txt (line 20)) (0.7.1)
# Requirement already satisfied: cryptography>=2.1.4 in /home/user/.local/lib/python3.10/site-packages (from azure-storage-blob==12.9.0->kserve==0.10.1->-r requirements.txt (line 20)) (41.0.1)
# Requirement already satisfied: attrs in /home/user/anaconda3/envs/mlops_eng/lib/python3.10/site-packages (from ray[serve]==2.0.0->kserve==0.10.1->-r requirements.txt (line 20)) (23.1.0)
# Requirement already satisfied: filelock in /home/user/anaconda3/envs/mlops_eng/lib/python3.10/site-packages (from ray[serve]==2.0.0->kserve==0.10.1->-r requirements.txt (line 20)) (3.12.4)
# Requirement already satisfied: msgpack<2.0.0,>=1.0.0 in /home/user/anaconda3/envs/mlops_eng/lib/python3.10/site-packages (from ray[serve]==2.0.0->kserve==0.10.1->-r requirements.txt (line 20)) (1.0.7)
# Requirement already satisfied: aiosignal in /home/user/anaconda3/envs/mlops_eng/lib/python3.10/site-packages (from ray[serve]==2.0.0->kserve==0.10.1->-r requirements.txt (line 20)) (1.3.1)
# Requirement already satisfied: frozenlist in /home/user/anaconda3/envs/mlops_eng/lib/python3.10/site-packages (from ray[serve]==2.0.0->kserve==0.10.1->-r requirements.txt (line 20)) (1.4.0)
# Requirement already satisfied: virtualenv in /home/user/anaconda3/envs/mlops_eng/lib/python3.10/site-packages (from ray[serve]==2.0.0->kserve==0.10.1->-r requirements.txt (line 20)) (20.24.5)
# Requirement already satisfied: aiohttp-cors in /home/user/anaconda3/envs/mlops_eng/lib/python3.10/site-packages (from ray[serve]==2.0.0->kserve==0.10.1->-r requirements.txt (line 20)) (0.7.0)
# Requirement already satisfied: py-spy>=0.2.0 in /home/user/anaconda3/envs/mlops_eng/lib/python3.10/site-packages (from ray[serve]==2.0.0->kserve==0.10.1->-r requirements.txt (line 20)) (0.3.14)
# Requirement already satisfied: gpustat>=1.0.0b1 in /home/user/anaconda3/envs/mlops_eng/lib/python3.10/site-packages (from ray[serve]==2.0.0->kserve==0.10.1->-r requirements.txt (line 20)) (1.1.1)
# Requirement already satisfied: aiorwlock in /home/user/anaconda3/envs/mlops_eng/lib/python3.10/site-packages (from ray[serve]==2.0.0->kserve==0.10.1->-r requirements.txt (line 20)) (1.3.0)
# Requirement already satisfied: colorful in /home/user/anaconda3/envs/mlops_eng/lib/python3.10/site-packages (from ray[serve]==2.0.0->kserve==0.10.1->-r requirements.txt (line 20)) (0.5.5)
# Requirement already satisfied: starlette in /home/user/anaconda3/envs/mlops_eng/lib/python3.10/site-packages (from ray[serve]==2.0.0->kserve==0.10.1->-r requirements.txt (line 20)) (0.22.0)
# Requirement already satisfied: smart-open in /home/user/anaconda3/envs/mlops_eng/lib/python3.10/site-packages (from ray[serve]==2.0.0->kserve==0.10.1->-r requirements.txt (line 20)) (6.4.0)
# Requirement already satisfied: opencensus in /home/user/anaconda3/envs/mlops_eng/lib/python3.10/site-packages (from ray[serve]==2.0.0->kserve==0.10.1->-r requirements.txt (line 20)) (0.11.3)
# Requirement already satisfied: uvicorn==0.16.0 in /home/user/anaconda3/envs/mlops_eng/lib/python3.10/site-packages (from ray[serve]==2.0.0->kserve==0.10.1->-r requirements.txt (line 20)) (0.16.0)
# Requirement already satisfied: aiohttp>=3.7 in /home/user/anaconda3/envs/mlops_eng/lib/python3.10/site-packages (from ray[serve]==2.0.0->kserve==0.10.1->-r requirements.txt (line 20)) (3.8.6)
# Requirement already satisfied: python-rapidjson>=0.9.1 in /home/user/anaconda3/envs/mlops_eng/lib/python3.10/site-packages (from tritonclient==2.18.0->kserve==0.10.1->-r requirements.txt (line 20)) (1.12)
# Requirement already satisfied: asgiref>=3.4.0 in /home/user/anaconda3/envs/mlops_eng/lib/python3.10/site-packages (from uvicorn==0.16.0->ray[serve]==2.0.0->kserve==0.10.1->-r requirements.txt (line 20)) (3.7.2)
# Requirement already satisfied: h11>=0.8 in /home/user/anaconda3/envs/mlops_eng/lib/python3.10/site-packages (from uvicorn==0.16.0->ray[serve]==2.0.0->kserve==0.10.1->-r requirements.txt (line 20)) (0.14.0)
# Requirement already satisfied: google-cloud-core<3.0dev,>=1.6.0 in /home/user/anaconda3/envs/mlops_eng/lib/python3.10/site-packages (from google-cloud-storage~=1.44.0->-r requirements.txt (line 4)) (2.3.3)
# Requirement already satisfied: google-resumable-media<3.0dev,>=1.3.0 in /home/user/anaconda3/envs/mlops_eng/lib/python3.10/site-packages (from google-cloud-storage~=1.44.0->-r requirements.txt (line 4)) (2.6.0)
# Requirement already satisfied: botocore<1.32.0,>=1.31.62 in /home/user/anaconda3/envs/mlops_eng/lib/python3.10/site-packages (from boto3~=1.28.62->-r requirements.txt (line 5)) (1.31.62)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /home/user/anaconda3/envs/mlops_eng/lib/python3.10/site-packages (from boto3~=1.28.62->-r requirements.txt (line 5)) (1.0.1)
# Requirement already satisfied: s3transfer<0.8.0,>=0.7.0 in /home/user/anaconda3/envs/mlops_eng/lib/python3.10/site-packages (from boto3~=1.28.62->-r requirements.txt (line 5)) (0.7.0)
# Requirement already satisfied: jsonpickle>=2 in /home/user/anaconda3/envs/mlops_eng/lib/python3.10/site-packages (from deepchecks~=0.17.4->-r requirements.txt (line 6)) (3.0.2)
# Requirement already satisfied: PyNomaly>=0.3.3 in /home/user/anaconda3/envs/mlops_eng/lib/python3.10/site-packages (from deepchecks~=0.17.4->-r requirements.txt (line 6)) (0.3.3)
# Requirement already satisfied: typing-extensions>=4.0.0 in /home/user/anaconda3/envs/mlops_eng/lib/python3.10/site-packages (from deepchecks~=0.17.4->-r requirements.txt (line 6)) (4.8.0)
# Requirement already satisfied: tqdm>=4.62.3 in /home/user/anaconda3/envs/mlops_eng/lib/python3.10/site-packages (from deepchecks~=0.17.4->-r requirements.txt (line 6)) (4.66.1)
# Requirement already satisfied: category-encoders>=2.3.0 in /home/user/anaconda3/envs/mlops_eng/lib/python3.10/site-packages (from deepchecks~=0.17.4->-r requirements.txt (line 6)) (2.6.2)
# Requirement already satisfied: pyzmq<24.0.0 in /home/user/anaconda3/envs/mlops_eng/lib/python3.10/site-packages (from deepchecks~=0.17.4->-r requirements.txt (line 6)) (23.2.1)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in /home/user/anaconda3/envs/mlops_eng/lib/python3.10/site-packages (from deepchecks~=0.17.4->-r requirements.txt (line 6)) (4.12.2)
# Requirement already satisfied: statsmodels>=0.13.5 in /home/user/anaconda3/envs/mlops_eng/lib/python3.10/site-packages (from deepchecks~=0.17.4->-r requirements.txt (line 6)) (0.14.0)
# Requirement already satisfied: ipython<8,>=7.15.0 in /home/user/anaconda3/envs/mlops_eng/lib/python3.10/site-packages (from deepchecks~=0.17.4->-r requirements.txt (line 6)) (7.34.0)
# Requirement already satisfied: ipykernel>=5.3.0 in /home/user/anaconda3/envs/mlops_eng/lib/python3.10/site-packages (from deepchecks~=0.17.4->-r requirements.txt (line 6)) (6.19.2)
# Requirement already satisfied: ipywidgets<8,>=7.6.5 in /home/user/anaconda3/envs/mlops_eng/lib/python3.10/site-packages (from deepchecks~=0.17.4->-r requirements.txt (line 6)) (7.8.1)
# Requirement already satisfied: wheel in /home/user/anaconda3/envs/mlops_eng/lib/python3.10/site-packages (from lightgbm~=3.3.5->-r requirements.txt (line 7)) (0.38.4)
# Requirement already satisfied: Werkzeug>=2.2.2 in /home/user/anaconda3/envs/mlops_eng/lib/python3.10/site-packages (from flask~=2.2.5->-r requirements.txt (line 8)) (3.0.0)
# Requirement already satisfied: itsdangerous>=2.0 in /home/user/anaconda3/envs/mlops_eng/lib/python3.10/site-packages (from flask~=2.2.5->-r requirements.txt (line 8)) (2.1.2)
# Collecting altair<5.0.0,>=4.2.1 (from great_expectations~=0.17.17->-r requirements.txt (line 11))
#   Downloading altair-4.2.2-py3-none-any.whl (813 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 813.6/813.6 kB 11.4 MB/s eta 0:00:00m eta 0:00:010:01
# Collecting colorama>=0.4.3 (from great_expectations~=0.17.17->-r requirements.txt (line 11))
#   Downloading colorama-0.4.6-py2.py3-none-any.whl (25 kB)
# Requirement already satisfied: jsonpatch>=1.22 in /home/user/anaconda3/envs/mlops_eng/lib/python3.10/site-packages (from great_expectations~=0.17.17->-r requirements.txt (line 11)) (1.33)
# Collecting makefun<2,>=1.7.0 (from great_expectations~=0.17.17->-r requirements.txt (line 11))
#   Downloading makefun-1.15.1-py2.py3-none-any.whl (22 kB)
# Collecting marshmallow<4.0.0,>=3.7.1 (from great_expectations~=0.17.17->-r requirements.txt (line 11))
#   Downloading marshmallow-3.20.1-py3-none-any.whl (49 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.4/49.4 kB 7.6 MB/s eta 0:00:00
# Requirement already satisfied: mistune>=0.8.4 in /home/user/anaconda3/envs/mlops_eng/lib/python3.10/site-packages (from great_expectations~=0.17.17->-r requirements.txt (line 11)) (3.0.2)
# Requirement already satisfied: nbformat>=5.0 in /home/user/anaconda3/envs/mlops_eng/lib/python3.10/site-packages (from great_expectations~=0.17.17->-r requirements.txt (line 11)) (5.9.2)
# Requirement already satisfied: notebook>=6.4.10 in /home/user/anaconda3/envs/mlops_eng/lib/python3.10/site-packages (from great_expectations~=0.17.17->-r requirements.txt (line 11)) (6.5.6)
# Requirement already satisfied: pyparsing>=2.4 in /home/user/anaconda3/envs/mlops_eng/lib/python3.10/site-packages (from great_expectations~=0.17.17->-r requirements.txt (line 11)) (3.1.1)
# Collecting ruamel.yaml<0.17.18,>=0.16 (from great_expectations~=0.17.17->-r requirements.txt (line 11))
#   Downloading ruamel.yaml-0.17.17-py3-none-any.whl (109 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 109.1/109.1 kB 8.1 MB/s eta 0:00:00
# Collecting tzlocal>=1.2 (from great_expectations~=0.17.17->-r requirements.txt (line 11))
#   Downloading tzlocal-5.2-py3-none-any.whl (17 kB)
# Collecting rapidfuzz<4.0.0,>=3.0.0 (from thefuzz~=0.20.0->-r requirements.txt (line 12))
#   Downloading rapidfuzz-3.5.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 11.7 MB/s eta 0:00:00m eta 0:00:010:01:01
# Requirement already satisfied: cmaes>=0.10.0 in /home/user/anaconda3/envs/mlops_eng/lib/python3.10/site-packages (from optuna~=3.3.0->-r requirements.txt (line 14)) (0.10.0)
# Requirement already satisfied: colorlog in /home/user/anaconda3/envs/mlops_eng/lib/python3.10/site-packages (from optuna~=3.3.0->-r requirements.txt (line 14)) (6.7.0)
# Requirement already satisfied: tenacity>=6.2.0 in /home/user/anaconda3/envs/mlops_eng/lib/python3.10/site-packages (from plotly~=5.15.0->-r requirements.txt (line 17)) (8.2.3)
# Requirement already satisfied: PyJWT<3,>=1.0.0 in /home/user/anaconda3/envs/mlops_eng/lib/python3.10/site-packages (from adal>=1.2.7->kserve==0.10.1->-r requirements.txt (line 20)) (2.8.0)
# Requirement already satisfied: Mako in /home/user/anaconda3/envs/mlops_eng/lib/python3.10/site-packages (from alembic!=1.10.0,<2->mlflow==2.3.2->-r requirements.txt (line 3)) (1.2.4)
# Collecting toolz (from altair<5.0.0,>=4.2.1->great_expectations~=0.17.17->-r requirements.txt (line 11))
#   Downloading toolz-0.12.0-py3-none-any.whl (55 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.8/55.8 kB 6.9 MB/s eta 0:00:00
# Requirement already satisfied: msal<2.0.0,>=1.20.0 in /home/user/anaconda3/envs/mlops_eng/lib/python3.10/site-packages (from azure-identity>=1.8.0->kserve==0.10.1->-r requirements.txt (line 20)) (1.24.1)
# Requirement already satisfied: msal-extensions<2.0.0,>=0.3.0 in /home/user/anaconda3/envs/mlops_eng/lib/python3.10/site-packages (from azure-identity>=1.8.0->kserve==0.10.1->-r requirements.txt (line 20)) (1.0.0)
# Requirement already satisfied: soupsieve>1.2 in /home/user/anaconda3/envs/mlops_eng/lib/python3.10/site-packages (from beautifulsoup4>=4.11.1->deepchecks~=0.17.4->-r requirements.txt (line 6)) (2.5)
# Requirement already satisfied: patsy>=0.5.1 in /home/user/anaconda3/envs/mlops_eng/lib/python3.10/site-packages (from category-encoders>=2.3.0->deepchecks~=0.17.4->-r requirements.txt (line 6)) (0.5.3)
# Requirement already satisfied: deprecation<3.0,>=2.0 in /home/user/anaconda3/envs/mlops_eng/lib/python3.10/site-packages (from cloudevents>=1.6.2->kserve==0.10.1->-r requirements.txt (line 20)) (2.1.0)
# Requirement already satisfied: cffi>=1.12 in /home/user/.local/lib/python3.10/site-packages (from cryptography>=2.1.4->azure-storage-blob==12.9.0->kserve==0.10.1->-r requirements.txt (line 20)) (1.15.1)
# Requirement already satisfied: oauthlib>=3.1.0 in /home/user/anaconda3/envs/mlops_eng/lib/python3.10/site-packages (from databricks-cli<1,>=0.8.7->mlflow==2.3.2->-r requirements.txt (line 3)) (3.2.2)
# Requirement already satisfied: wrapt<2,>=1.10 in /home/user/anaconda3/envs/mlops_eng/lib/python3.10/site-packages (from Deprecated<2,>=1.2.7->kfp==1.8.22->-r requirements.txt (line 22)) (1.15.0)
# Requirement already satisfied: websocket-client>=0.32.0 in /home/user/anaconda3/envs/mlops_eng/lib/python3.10/site-packages (from docker<7,>=4.0.0->mlflow==2.3.2->-r requirements.txt (line 3)) (1.6.4)
# Requirement already satisfied: anyio<5,>=3.4.0 in /home/user/anaconda3/envs/mlops_eng/lib/python3.10/site-packages (from starlette->ray[serve]==2.0.0->kserve==0.10.1->-r requirements.txt (line 20)) (3.7.1)
# Requirement already satisfied: termcolor in /home/user/anaconda3/envs/mlops_eng/lib/python3.10/site-packages (from fire<1,>=0.3.1->kfp==1.8.22->-r requirements.txt (line 22)) (2.3.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /home/user/anaconda3/envs/mlops_eng/lib/python3.10/site-packages (from gitpython<4,>=2.1.0->mlflow==2.3.2->-r requirements.txt (line 3)) (4.0.10)
# Requirement already satisfied: googleapis-common-protos<2.0.dev0,>=1.56.2 in /home/user/anaconda3/envs/mlops_eng/lib/python3.10/site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->kfp==1.8.22->-r requirements.txt (line 22)) (1.60.0)
# Requirement already satisfied: httplib2<1dev,>=0.15.0 in /home/user/anaconda3/envs/mlops_eng/lib/python3.10/site-packages (from google-api-python-client<2,>=1.7.8->kfp==1.8.22->-r requirements.txt (line 22)) (0.22.0)
# Requirement already satisfied: google-auth-httplib2>=0.0.3 in /home/user/anaconda3/envs/mlops_eng/lib/python3.10/site-packages (from google-api-python-client<2,>=1.7.8->kfp==1.8.22->-r requirements.txt (line 22)) (0.1.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /home/user/anaconda3/envs/mlops_eng/lib/python3.10/site-packages (from google-auth<3,>=1.6.1->kfp==1.8.22->-r requirements.txt (line 22)) (5.3.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /home/user/anaconda3/envs/mlops_eng/lib/python3.10/site-packages (from google-auth<3,>=1.6.1->kfp==1.8.22->-r requirements.txt (line 22)) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /home/user/anaconda3/envs/mlops_eng/lib/python3.10/site-packages (from google-auth<3,>=1.6.1->kfp==1.8.22->-r requirements.txt (line 22)) (4.9)
# Requirement already satisfied: google-crc32c<2.0dev,>=1.0 in /home/user/anaconda3/envs/mlops_eng/lib/python3.10/site-packages (from google-resumable-media<3.0dev,>=1.3.0->google-cloud-storage~=1.44.0->-r requirements.txt (line 4)) (1.5.0)
# Requirement already satisfied: certifi in /home/user/anaconda3/envs/mlops_eng/lib/python3.10/site-packages (from httpx>=0.23.0->kserve==0.10.1->-r requirements.txt (line 20)) (2023.7.22)
# Requirement already satisfied: httpcore<0.19.0,>=0.18.0 in /home/user/anaconda3/envs/mlops_eng/lib/python3.10/site-packages (from httpx>=0.23.0->kserve==0.10.1->-r requirements.txt (line 20)) (0.18.0)
# Requirement already satisfied: idna in /home/user/anaconda3/envs/mlops_eng/lib/python3.10/site-packages (from httpx>=0.23.0->kserve==0.10.1->-r requirements.txt (line 20)) (3.4)
# Requirement already satisfied: sniffio in /home/user/anaconda3/envs/mlops_eng/lib/python3.10/site-packages (from httpx>=0.23.0->kserve==0.10.1->-r requirements.txt (line 20)) (1.3.0)
# Requirement already satisfied: zipp>=0.5 in /home/user/anaconda3/envs/mlops_eng/lib/python3.10/site-packages (from importlib-metadata!=4.7.0,<7,>=3.7.0->mlflow==2.3.2->-r requirements.txt (line 3)) (3.17.0)
# Requirement already satisfied: comm>=0.1.1 in /home/user/anaconda3/envs/mlops_eng/lib/python3.10/site-packages (from ipykernel>=5.3.0->deepchecks~=0.17.4->-r requirements.txt (line 6)) (0.1.4)
# Requirement already satisfied: debugpy>=1.0 in /home/user/anaconda3/envs/mlops_eng/lib/python3.10/site-packages (from ipykernel>=5.3.0->deepchecks~=0.17.4->-r requirements.txt (line 6)) (1.5.1)
# Requirement already satisfied: jupyter-client>=6.1.12 in /home/user/anaconda3/envs/mlops_eng/lib/python3.10/site-packages (from ipykernel>=5.3.0->deepchecks~=0.17.4->-r requirements.txt (line 6)) (7.4.9)
# Requirement already satisfied: matplotlib-inline>=0.1 in /home/user/anaconda3/envs/mlops_eng/lib/python3.10/site-packages (from ipykernel>=5.3.0->deepchecks~=0.17.4->-r requirements.txt (line 6)) (0.1.6)
# Requirement already satisfied: nest-asyncio in /home/user/anaconda3/envs/mlops_eng/lib/python3.10/site-packages (from ipykernel>=5.3.0->deepchecks~=0.17.4->-r requirements.txt (line 6)) (1.5.6)
# Requirement already satisfied: tornado>=6.1 in /home/user/anaconda3/envs/mlops_eng/lib/python3.10/site-packages (from ipykernel>=5.3.0->deepchecks~=0.17.4->-r requirements.txt (line 6)) (6.2)
# Requirement already satisfied: traitlets>=5.4.0 in /home/user/anaconda3/envs/mlops_eng/lib/python3.10/site-packages (from ipykernel>=5.3.0->deepchecks~=0.17.4->-r requirements.txt (line 6)) (5.7.1)
# Requirement already satisfied: jedi>=0.16 in /home/user/anaconda3/envs/mlops_eng/lib/python3.10/site-packages (from ipython<8,>=7.15.0->deepchecks~=0.17.4->-r requirements.txt (line 6)) (0.18.1)
# Requirement already satisfied: decorator in /home/user/anaconda3/envs/mlops_eng/lib/python3.10/site-packages (from ipython<8,>=7.15.0->deepchecks~=0.17.4->-r requirements.txt (line 6)) (5.1.1)
# Requirement already satisfied: pickleshare in /home/user/anaconda3/envs/mlops_eng/lib/python3.10/site-packages (from ipython<8,>=7.15.0->deepchecks~=0.17.4->-r requirements.txt (line 6)) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /home/user/anaconda3/envs/mlops_eng/lib/python3.10/site-packages (from ipython<8,>=7.15.0->deepchecks~=0.17.4->-r requirements.txt (line 6)) (3.0.36)
# Requirement already satisfied: pygments in /home/user/anaconda3/envs/mlops_eng/lib/python3.10/site-packages (from ipython<8,>=7.15.0->deepchecks~=0.17.4->-r requirements.txt (line 6)) (2.15.1)
# Requirement already satisfied: backcall in /home/user/anaconda3/envs/mlops_eng/lib/python3.10/site-packages (from ipython<8,>=7.15.0->deepchecks~=0.17.4->-r requirements.txt (line 6)) (0.2.0)
# Requirement already satisfied: pexpect>4.3 in /home/user/anaconda3/envs/mlops_eng/lib/python3.10/site-packages (from ipython<8,>=7.15.0->deepchecks~=0.17.4->-r requirements.txt (line 6)) (4.8.0)
# Requirement already satisfied: ipython-genutils~=0.2.0 in /home/user/anaconda3/envs/mlops_eng/lib/python3.10/site-packages (from ipywidgets<8,>=7.6.5->deepchecks~=0.17.4->-r requirements.txt (line 6)) (0.2.0)
# Requirement already satisfied: widgetsnbextension~=3.6.6 in /home/user/anaconda3/envs/mlops_eng/lib/python3.10/site-packages (from ipywidgets<8,>=7.6.5->deepchecks~=0.17.4->-r requirements.txt (line 6)) (3.6.6)
# Requirement already satisfied: jupyterlab-widgets<3,>=1.0.0 in /home/user/anaconda3/envs/mlops_eng/lib/python3.10/site-packages (from ipywidgets<8,>=7.6.5->deepchecks~=0.17.4->-r requirements.txt (line 6)) (1.1.7)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/user/.local/lib/python3.10/site-packages (from Jinja2<4,>=2.11->mlflow==2.3.2->-r requirements.txt (line 3)) (2.1.3)
# Requirement already satisfied: jsonpointer>=1.9 in /home/user/anaconda3/envs/mlops_eng/lib/python3.10/site-packages (from jsonpatch>=1.22->great_expectations~=0.17.17->-r requirements.txt (line 11)) (2.4)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /home/user/anaconda3/envs/mlops_eng/lib/python3.10/site-packages (from jsonschema<5,>=3.0.1->kfp==1.8.22->-r requirements.txt (line 22)) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in /home/user/anaconda3/envs/mlops_eng/lib/python3.10/site-packages (from jsonschema<5,>=3.0.1->kfp==1.8.22->-r requirements.txt (line 22)) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /home/user/anaconda3/envs/mlops_eng/lib/python3.10/site-packages (from jsonschema<5,>=3.0.1->kfp==1.8.22->-r requirements.txt (line 22)) (0.10.4)
# Requirement already satisfied: requests-oauthlib in /home/user/anaconda3/envs/mlops_eng/lib/python3.10/site-packages (from kubernetes>=18.20.0->kserve==0.10.1->-r requirements.txt (line 20)) (1.3.1)
# Requirement already satisfied: contourpy>=1.0.1 in /home/user/anaconda3/envs/mlops_eng/lib/python3.10/site-packages (from matplotlib<4->mlflow==2.3.2->-r requirements.txt (line 3)) (1.1.1)
# Requirement already satisfied: cycler>=0.10 in /home/user/anaconda3/envs/mlops_eng/lib/python3.10/site-packages (from matplotlib<4->mlflow==2.3.2->-r requirements.txt (line 3)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/user/anaconda3/envs/mlops_eng/lib/python3.10/site-packages (from matplotlib<4->mlflow==2.3.2->-r requirements.txt (line 3)) (4.43.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/user/anaconda3/envs/mlops_eng/lib/python3.10/site-packages (from matplotlib<4->mlflow==2.3.2->-r requirements.txt (line 3)) (1.4.5)
# Requirement already satisfied: pillow>=6.2.0 in /home/user/anaconda3/envs/mlops_eng/lib/python3.10/site-packages (from matplotlib<4->mlflow==2.3.2->-r requirements.txt (line 3)) (10.0.1)
# Requirement already satisfied: fastjsonschema in /home/user/anaconda3/envs/mlops_eng/lib/python3.10/site-packages (from nbformat>=5.0->great_expectations~=0.17.17->-r requirements.txt (line 11)) (2.18.1)
# Requirement already satisfied: jupyter-core in /home/user/anaconda3/envs/mlops_eng/lib/python3.10/site-packages (from nbformat>=5.0->great_expectations~=0.17.17->-r requirements.txt (line 11)) (5.3.0)
# Requirement already satisfied: argon2-cffi in /home/user/anaconda3/envs/mlops_eng/lib/python3.10/site-packages (from notebook>=6.4.10->great_expectations~=0.17.17->-r requirements.txt (line 11)) (23.1.0)
# Requirement already satisfied: nbconvert>=5 in /home/user/anaconda3/envs/mlops_eng/lib/python3.10/site-packages (from notebook>=6.4.10->great_expectations~=0.17.17->-r requirements.txt (line 11)) (7.9.2)
# Requirement already satisfied: Send2Trash>=1.8.0 in /home/user/anaconda3/envs/mlops_eng/lib/python3.10/site-packages (from notebook>=6.4.10->great_expectations~=0.17.17->-r requirements.txt (line 11)) (1.8.2)
# Requirement already satisfied: terminado>=0.8.3 in /home/user/anaconda3/envs/mlops_eng/lib/python3.10/site-packages (from notebook>=6.4.10->great_expectations~=0.17.17->-r requirements.txt (line 11)) (0.17.1)
# Requirement already satisfied: nbclassic>=0.4.7 in /home/user/anaconda3/envs/mlops_eng/lib/python3.10/site-packages (from notebook>=6.4.10->great_expectations~=0.17.17->-r requirements.txt (line 11)) (1.0.0)
# Requirement already satisfied: python-utils in /home/user/anaconda3/envs/mlops_eng/lib/python3.10/site-packages (from PyNomaly>=0.3.3->deepchecks~=0.17.4->-r requirements.txt (line 6)) (3.8.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/user/anaconda3/envs/mlops_eng/lib/python3.10/site-packages (from requests<3,>=2.17.3->mlflow==2.3.2->-r requirements.txt (line 3)) (3.3.0)
# Requirement already satisfied: greenlet!=0.4.17 in /home/user/anaconda3/envs/mlops_eng/lib/python3.10/site-packages (from sqlalchemy<3,>=1.4.0->mlflow==2.3.2->-r requirements.txt (line 3)) (3.0.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/user/anaconda3/envs/mlops_eng/lib/python3.10/site-packages (from aiohttp>=3.7->ray[serve]==2.0.0->kserve==0.10.1->-r requirements.txt (line 20)) (6.0.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /home/user/anaconda3/envs/mlops_eng/lib/python3.10/site-packages (from aiohttp>=3.7->ray[serve]==2.0.0->kserve==0.10.1->-r requirements.txt (line 20)) (4.0.3)
# Requirement already satisfied: yarl<2.0,>=1.0 in /home/user/anaconda3/envs/mlops_eng/lib/python3.10/site-packages (from aiohttp>=3.7->ray[serve]==2.0.0->kserve==0.10.1->-r requirements.txt (line 20)) (1.9.2)
# Requirement already satisfied: pycparser in /home/user/.local/lib/python3.10/site-packages (from cffi>=1.12->cryptography>=2.1.4->azure-storage-blob==12.9.0->kserve==0.10.1->-r requirements.txt (line 20)) (2.21)
# Requirement already satisfied: smmap<6,>=3.0.1 in /home/user/anaconda3/envs/mlops_eng/lib/python3.10/site-packages (from gitdb<5,>=4.0.1->gitpython<4,>=2.1.0->mlflow==2.3.2->-r requirements.txt (line 3)) (5.0.1)
# Requirement already satisfied: nvidia-ml-py>=11.450.129 in /home/user/anaconda3/envs/mlops_eng/lib/python3.10/site-packages (from gpustat>=1.0.0b1->ray[serve]==2.0.0->kserve==0.10.1->-r requirements.txt (line 20)) (12.535.108)
# Requirement already satisfied: blessed>=1.17.1 in /home/user/anaconda3/envs/mlops_eng/lib/python3.10/site-packages (from gpustat>=1.0.0b1->ray[serve]==2.0.0->kserve==0.10.1->-r requirements.txt (line 20)) (1.20.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /home/user/anaconda3/envs/mlops_eng/lib/python3.10/site-packages (from jedi>=0.16->ipython<8,>=7.15.0->deepchecks~=0.17.4->-r requirements.txt (line 6)) (0.8.3)
# Requirement already satisfied: platformdirs>=2.5 in /home/user/anaconda3/envs/mlops_eng/lib/python3.10/site-packages (from jupyter-core->nbformat>=5.0->great_expectations~=0.17.17->-r requirements.txt (line 11)) (3.11.0)
# Requirement already satisfied: portalocker<3,>=1.0 in /home/user/anaconda3/envs/mlops_eng/lib/python3.10/site-packages (from msal-extensions<2.0.0,>=0.3.0->azure-identity>=1.8.0->kserve==0.10.1->-r requirements.txt (line 20)) (2.8.2)
# Requirement already satisfied: isodate>=0.6.0 in /home/user/anaconda3/envs/mlops_eng/lib/python3.10/site-packages (from msrest>=0.6.21->azure-storage-blob==12.9.0->kserve==0.10.1->-r requirements.txt (line 20)) (0.6.1)
# Requirement already satisfied: jupyter-server>=1.8 in /home/user/anaconda3/envs/mlops_eng/lib/python3.10/site-packages (from nbclassic>=0.4.7->notebook>=6.4.10->great_expectations~=0.17.17->-r requirements.txt (line 11)) (1.24.0)
# Requirement already satisfied: notebook-shim>=0.2.3 in /home/user/anaconda3/envs/mlops_eng/lib/python3.10/site-packages (from nbclassic>=0.4.7->notebook>=6.4.10->great_expectations~=0.17.17->-r requirements.txt (line 11)) (0.2.3)
# Requirement already satisfied: bleach!=5.0.0 in /home/user/anaconda3/envs/mlops_eng/lib/python3.10/site-packages (from nbconvert>=5->notebook>=6.4.10->great_expectations~=0.17.17->-r requirements.txt (line 11)) (6.1.0)
# Requirement already satisfied: defusedxml in /home/user/anaconda3/envs/mlops_eng/lib/python3.10/site-packages (from nbconvert>=5->notebook>=6.4.10->great_expectations~=0.17.17->-r requirements.txt (line 11)) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in /home/user/anaconda3/envs/mlops_eng/lib/python3.10/site-packages (from nbconvert>=5->notebook>=6.4.10->great_expectations~=0.17.17->-r requirements.txt (line 11)) (0.2.2)
# Requirement already satisfied: nbclient>=0.5.0 in /home/user/anaconda3/envs/mlops_eng/lib/python3.10/site-packages (from nbconvert>=5->notebook>=6.4.10->great_expectations~=0.17.17->-r requirements.txt (line 11)) (0.8.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in /home/user/anaconda3/envs/mlops_eng/lib/python3.10/site-packages (from nbconvert>=5->notebook>=6.4.10->great_expectations~=0.17.17->-r requirements.txt (line 11)) (1.5.0)
# Requirement already satisfied: tinycss2 in /home/user/anaconda3/envs/mlops_eng/lib/python3.10/site-packages (from nbconvert>=5->notebook>=6.4.10->great_expectations~=0.17.17->-r requirements.txt (line 11)) (1.2.1)
# Requirement already satisfied: ptyprocess>=0.5 in /home/user/anaconda3/envs/mlops_eng/lib/python3.10/site-packages (from pexpect>4.3->ipython<8,>=7.15.0->deepchecks~=0.17.4->-r requirements.txt (line 6)) (0.7.0)
# Requirement already satisfied: wcwidth in /home/user/anaconda3/envs/mlops_eng/lib/python3.10/site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython<8,>=7.15.0->deepchecks~=0.17.4->-r requirements.txt (line 6)) (0.2.5)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /home/user/anaconda3/envs/mlops_eng/lib/python3.10/site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.1->kfp==1.8.22->-r requirements.txt (line 22)) (0.5.0)
# Requirement already satisfied: argon2-cffi-bindings in /home/user/anaconda3/envs/mlops_eng/lib/python3.10/site-packages (from argon2-cffi->notebook>=6.4.10->great_expectations~=0.17.17->-r requirements.txt (line 11)) (21.2.0)
# Requirement already satisfied: opencensus-context>=0.1.3 in /home/user/anaconda3/envs/mlops_eng/lib/python3.10/site-packages (from opencensus->ray[serve]==2.0.0->kserve==0.10.1->-r requirements.txt (line 20)) (0.1.3)
# Requirement already satisfied: distlib<1,>=0.3.7 in /home/user/anaconda3/envs/mlops_eng/lib/python3.10/site-packages (from virtualenv->ray[serve]==2.0.0->kserve==0.10.1->-r requirements.txt (line 20)) (0.3.7)
# Requirement already satisfied: exceptiongroup in /home/user/anaconda3/envs/mlops_eng/lib/python3.10/site-packages (from anyio<5,>=3.4.0->starlette->ray[serve]==2.0.0->kserve==0.10.1->-r requirements.txt (line 20)) (1.1.3)
# Requirement already satisfied: webencodings in /home/user/anaconda3/envs/mlops_eng/lib/python3.10/site-packages (from bleach!=5.0.0->nbconvert>=5->notebook>=6.4.10->great_expectations~=0.17.17->-r requirements.txt (line 11)) (0.5.1)
# Installing collected packages: makefun, argparse, tzlocal, toolz, ruamel.yaml, rapidfuzz, plotly, marshmallow, joblib, colorama, thefuzz, scikit-learn, flask, mlflow, altair, great_expectations
#   Attempting uninstall: plotly
#     Found existing installation: plotly 5.17.0
#     Uninstalling plotly-5.17.0:
#       Successfully uninstalled plotly-5.17.0
#   Attempting uninstall: joblib
#     Found existing installation: joblib 1.3.2
#     Uninstalling joblib-1.3.2:
#       Successfully uninstalled joblib-1.3.2
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 1.3.1
#     Uninstalling scikit-learn-1.3.1:
#       Successfully uninstalled scikit-learn-1.3.1
#   Attempting uninstall: flask
#     Found existing installation: Flask 2.3.3
#     Uninstalling Flask-2.3.3:
#       Successfully uninstalled Flask-2.3.3
#   Attempting uninstall: mlflow
#     Found existing installation: mlflow 2.3.0
#     Uninstalling mlflow-2.3.0:
#       Successfully uninstalled mlflow-2.3.0
# Successfully installed altair-4.2.2 argparse-1.4.0 colorama-0.4.6 flask-2.2.5 great_expectations-0.17.23 joblib-1.2.0 makefun-1.15.1 marshmallow-3.20.1 mlflow-2.3.2 plotly-5.15.0 rapidfuzz-3.5.1 ruamel.yaml-0.17.17 scikit-learn-1.3.2 thefuzz-0.20.0 toolz-0.12.0 tzlocal-5.2
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ### Week 1 tutorials
# In this week, we'll focus on tracking model training using MLflow. Specifically, you'll learn how to log model training metadata and upload trained models to MLflow. You'll also learn how to use [Deepchecks](https://docs.deepchecks.com/stable/getting-started/welcome.html) to evaluate a trained model. As the course progresses in the upcoming weeks, you'll learn more about KServe and Kubeflow Pipelines.
#
# Below are the links to the MLflow and Deepchecks tutorial.
#
# * [MLflow tutorial](./tutorials/1_try_mlflow.ipynb)
# * [Deepchecks tutorial](./tutorials/2_try_deepchecks.ipynb)
